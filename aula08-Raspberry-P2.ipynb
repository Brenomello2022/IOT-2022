# %%
import RPi.GPIO as gpio
import os
import time as delay
from urllib.request import urlopen
import requests

gpio.setmode(gpio.BOARD)

ledvermelho, ledverde = 11, 12
contador = 0
botao = 18
cl1 = True
cl2 = True 
cl3 = True
cl4 = True 
cl5 = True

gpio.setup(ledvermelho, gpio.OUT)
gpio.setup(ledverde, gpio.OUT)
gpio.setup(botao, gpio.IN)

gpio.output(ledvermelho, False)
gpio.output(ledverde, False)

while True:
    if (gpio.input(18)) == True:
        contador = contador + 1
         
    if contador == 1 and cl1 == True:
        cl1 = False
        gpio.output(ledvermelho, True)
        delay.sleep(2)
        gpio.output(ledvermelho, False)
        consulta1 = requests.get('')
        consulta2 = requests.get('')
        consulta3 = requests.get('')
        consulta4 = requests.get('')
        print('Leitura finalizada')
        if (float(consulta1.text) <= 0):
            print('Ocupacao Invalida')
            gpio.output(ledvermelho, True)
            delay.sleep(1)
            gpio.output(ledvermelho, False)
            delay.sleep(1)
            gpio.output(ledvermelho, True)
            delay.sleep(1)
            gpio.output(ledvermelho, False)
            delay.sleep(1)
            gpio.output(ledvermelho, True)
            delay.sleep(1)
            gpio.output(ledvermelho, False)
            delay.sleep(1)
        else:
            print('Ocupacao Valida' +str(consulta1.text))
            gpio.output(ledverde, True)
            delay.sleep(1)
            gpio.output(ledverde, False)
            delay.sleep(1)
            gpio.output(ledverde, True)
            delay.sleep(1)
            gpio.output(ledverde, False)
            delay.sleep(1)
            gpio.output(ledverde, True)
            delay.sleep(1)
            gpio.output(ledverde, False)
            delay.sleep(1)
            print('Temperatura '+consulta1.text)
            
        if (float(consulta2.text) <= 0):
            print('Ocupacao Invalida')
            gpio.output(ledvermelho, True)
            delay.sleep(1)
            gpio.output(ledvermelho, False)
            delay.sleep(1)
            gpio.output(ledvermelho, True)
            delay.sleep(1)
            gpio.output(ledvermelho, False)
            delay.sleep(1)
            gpio.output(ledvermelho, True)
            delay.sleep(1)
            gpio.output(ledvermelho, False)
            delay.sleep(1)
        else:
            print('Ocupacao Valida' +str(consulta2.text))
            gpio.output(ledverde, True)
            delay.sleep(1)
            gpio.output(ledverde, False)
            delay.sleep(1)
            gpio.output(ledverde, True)
            delay.sleep(1)
            gpio.output(ledverde, False)
            delay.sleep(1)
            gpio.output(ledverde, True)
            delay.sleep(1)
            gpio.output(ledverde, False)
            delay.sleep(1)
            print('Umidade '+consulta2.text)

        if (float(consulta3.text) <= 0):
            print('Ocupacao Invalida')
            gpio.output(ledvermelho, True)
            delay.sleep(1)
            gpio.output(ledvermelho, False)
            delay.sleep(1)
            gpio.output(ledvermelho, True)
            delay.sleep(1)
            gpio.output(ledvermelho, False)
            delay.sleep(1)
            gpio.output(ledvermelho, True)
            delay.sleep(1)
            gpio.output(ledvermelho, False)
            delay.sleep(1)
            cl3 = False
        else:
            print('Ocupacao Valida' +str(consulta3.text))
            gpio.output(ledverde, True)
            delay.sleep(1)
            gpio.output(ledverde, False)
            delay.sleep(1)
            gpio.output(ledverde, True)
            delay.sleep(1)
            gpio.output(ledverde, False)
            delay.sleep(1)
            gpio.output(ledverde, True)
            delay.sleep(1)
            gpio.output(ledverde, False)
            delay.sleep(1)
            print('Distancia '+consulta3.text)

        if (float(consulta4.text) <= 0):
            print('Ocupacao Invalida')
            gpio.output(ledvermelho, True)
            delay.sleep(1)
            gpio.output(ledvermelho, False)
            delay.sleep(1)
            gpio.output(ledvermelho, True)
            delay.sleep(1)
            gpio.output(ledvermelho, False)
            delay.sleep(1)
            gpio.output(ledvermelho, True)
            delay.sleep(1)
            gpio.output(ledvermelho, False)
            delay.sleep(1)
        else:
            print('Ocupacao Valida' +str(consulta4.text))
            gpio.output(ledverde, True)
            delay.sleep(1)
            gpio.output(ledverde, False)
            delay.sleep(1)
            gpio.output(ledverde, True)
            delay.sleep(1)
            gpio.output(ledverde, False)
            delay.sleep(1)
            gpio.output(ledverde, True)
            delay.sleep(1)
            gpio.output(ledverde, False)
            delay.sleep(1) 
            print('Ocupação '+consulta4.text)
            
    if contador == 2 and cl2 == True:
        cl2 = False
        print('Finalizado')
